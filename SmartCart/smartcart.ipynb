# %% [markdown]
# # E-Commerce Customer Segmentation System

# %%
"""Importing the Libaraies"""
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("smartcart_customers.csv")

# %%
df.head()
# Out:
#      ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0  5524        1957  Graduation         Single  58138.0        0         0
# 1  2174        1954  Graduation         Single  46344.0        1         1
# 2  4141        1965  Graduation       Together  71613.0        0         0
# 3  6182        1984  Graduation       Together  26646.0        1         0
# 4  5324        1981         PhD        Married  58293.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0  04-09-2012       58       635  ...              172                88
# 1  08-03-2014       38        11  ...                2                 1
# 2  21-08-2013       26       426  ...              111                21
# 3  10-02-2014       26        11  ...               10                 3
# 4  19-01-2014       94       173  ...               46                27
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ...

# %%
df.shape
# Out:
# (2240, 22)

# %%
df.isnull().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Complain                0
# Response                0
# dtype: int64

# %% [markdown]
# ## Data PreProcessing

# %% [markdown]
# ### 1. Handle Missing Values

# %%
# Handle missing values
df["Income"] = df["Income"].fillna(df["Income"].median())

# %%
df.isnull().sum() # No missing Values
df.head()
# Out:
#      ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0  5524        1957  Graduation         Single  58138.0        0         0
# 1  2174        1954  Graduation         Single  46344.0        1         1
# 2  4141        1965  Graduation       Together  71613.0        0         0
# 3  6182        1984  Graduation       Together  26646.0        1         0
# 4  5324        1981         PhD        Married  58293.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0  04-09-2012       58       635  ...              172                88
# 1  08-03-2014       38        11  ...                2                 1
# 2  21-08-2013       26       426  ...              111                21
# 3  10-02-2014       26        11  ...               10                 3
# 4  19-01-2014       94       173  ...               46                27
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ...

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### Transforming the feature into meaningful content
# #### Year of birth --> Age
# #### Dt_cutomer ---> Customer Tenure

# %%
# Age 
df["Age"] = 2026-df["Year_Birth"]

# %%
df.head()
# Out:
#      ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0  5524        1957  Graduation         Single  58138.0        0         0
# 1  2174        1954  Graduation         Single  46344.0        1         1
# 2  4141        1965  Graduation       Together  71613.0        0         0
# 3  6182        1984  Graduation       Together  26646.0        1         0
# 4  5324        1981         PhD        Married  58293.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntSweetProducts  MntGoldProds  \
# 0  04-09-2012       58       635  ...                88            88
# 1  08-03-2014       38        11  ...                 1             6
# 2  21-08-2013       26       426  ...                21            42
# 3  10-02-2014       26        11  ...                 3             5
# 4  19-01-2014       94       173  ...                27            15
#
#    NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# ...

# %%
# Customer Joing Date ---- Convert into DateTime
df["Dt_Customer"] = pd.to_datetime(df["Dt_Customer"], dayfirst=True)
reference_date = df["Dt_Customer"].max()

# We can’t use datetime.now here, but it will show current date, so revising this project after month will fluctuate data.So,to make data reproducable we use max() — to get the same results every time.  

df["Customer_Tenure_Days"] = (reference_date - df["Dt_Customer"]).dt.days

# %%
df.head() # New Feature - Customer_Tenure_Days
# Out:
#      ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0  5524        1957  Graduation         Single  58138.0        0         0
# 1  2174        1954  Graduation         Single  46344.0        1         1
# 2  4141        1965  Graduation       Together  71613.0        0         0
# 3  6182        1984  Graduation       Together  26646.0        1         0
# 4  5324        1981         PhD        Married  58293.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntGoldProds  NumDealsPurchases  \
# 0  2012-09-04       58       635  ...            88                  3
# 1  2014-03-08       38        11  ...             6                  2
# 2  2013-08-21       26       426  ...            42                  1
# 3  2014-02-10       26        11  ...             5                  2
# 4  2014-01-19       94       173  ...            15                  5
#
#    NumWebPurchases  NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  \
# ...

# %% [markdown]
# #### Combine all the spending into one.
# ##### Total = Wines + Fruits + Fish + meat + Sweets + gold

# %%
# Total Spending
df["Total_Spending"] = df["MntWines"] + df["MntFruits"] + df["MntMeatProducts"] + df["MntFishProducts"] + df["MntSweetProducts"] + df["MntGoldProds"]

# %%
df.head() # Total_Spending feature
# Out:
#      ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0  5524        1957  Graduation         Single  58138.0        0         0
# 1  2174        1954  Graduation         Single  46344.0        1         1
# 2  4141        1965  Graduation       Together  71613.0        0         0
# 3  6182        1984  Graduation       Together  26646.0        1         0
# 4  5324        1981         PhD        Married  58293.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  NumDealsPurchases  NumWebPurchases  \
# 0  2012-09-04       58       635  ...                  3                8
# 1  2014-03-08       38        11  ...                  2                1
# 2  2013-08-21       26       426  ...                  1                8
# 3  2014-02-10       26        11  ...                  2                2
# 4  2014-01-19       94       173  ...                  5                5
#
# ...

# %% [markdown]
# ##### Adding children + Teenage into one category of child

# %%
# children feature 
df["Total_Child"] = df["Kidhome"] + df["Teenhome"]
df.head()
# Out:
#      ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0  5524        1957  Graduation         Single  58138.0        0         0
# 1  2174        1954  Graduation         Single  46344.0        1         1
# 2  4141        1965  Graduation       Together  71613.0        0         0
# 3  6182        1984  Graduation       Together  26646.0        1         0
# 4  5324        1981         PhD        Married  58293.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  NumWebPurchases  NumCatalogPurchases  \
# 0  2012-09-04       58       635  ...                8                   10
# 1  2014-03-08       38        11  ...                1                    1
# 2  2013-08-21       26       426  ...                8                    2
# 3  2014-02-10       26        11  ...                2                    0
# 4  2014-01-19       94       173  ...                5                    3
#
# ...

# %% [markdown]
# #### Education Feature -- Seggregate into 3 different categories
# ##### Undergraduate, Graduate, Post-Graduate

# %%
# Education Feature Engineering
df["Education"].value_counts()

# Undergraduate, Graduate, Post-Graduate
df["Education"] = df["Education"].replace({
    "Basic": "Undergraduate", "2n Cycle": "Undergraduate",
    "Graduation": "Graduate",
    "Master": "Postgraduate", "PhD": "Postgraduate"
})

# %%
df["Education"].value_counts()
# Out:
# Education
# Graduate         1127
# Postgraduate      856
# Undergraduate     257
# Name: count, dtype: int64

# %% [markdown]
# ### Marital Status -- Assigning with Single & Partner
# ##### Alone, Divorced, Single, Widow --> Living Single
# ##### Together, Married --> Living with Partner

# %%
# Martial Status Feature
df["Marital_Status"].value_counts()

df["Living_With"] = df["Marital_Status"].replace({
    "Married": "Partner", "Together": "Partner",
    "Single": "Alone", "Divorced": "Alone", "Widow": "Alone", "Alone": "Alone",
    "Absurd": "Alone", "YOLO": "Alone"
})
df["Living_With"].value_counts()
# Out:
# Living_With
# Partner    1444
# Alone       796
# Name: count, dtype: int64
